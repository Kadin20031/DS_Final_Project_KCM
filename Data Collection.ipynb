# %% [markdown]
# ### Imports

# %%
# Importing API libraries
from dotenv import load_dotenv
import os
import requests

# Handling API limits libraries
from concurrent.futures import as_completed, ProcessPoolExecutor
from requests_futures.sessions import FuturesSession
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import time

# SQL imports
from pangres import upsert
from sqlalchemy import text, create_engine

# Stanadard libraries 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Loading Data Into SQL Database Functions

# %%
# loading env information
db_username = os.environ.get('db_username')
db_password = os.environ.get('db_password')
db_host = os.environ.get('db_host')
db_port = os.environ.get('db_port')
db_name = os.environ.get('db_name')

# creating db url
def create_db_connection_str(db_username, db_password, db_host, db_port, db_name):
    connection_url = 'postgresql+psycopg2://'+db_username+':'+db_password+'@'+db_host+':'+db_port+'/'+db_name
    return connection_url

# creating db engine
def create_db_engine(db_username, db_password, db_host, db_port, db_name):
    db_url = create_db_connection_str(db_username, db_password, db_host, db_port, db_name)
    db_engine = create_engine(db_url, pool_recycle=3600, future=True)

    return db_engine

def upload_data_into_sql(dataframe,neededSchema,tablename):
    db_engine = create_db_engine(db_username, db_password, db_host, db_port, db_name)
    connection = db_engine.connect()
    upsert(con=connection,df=dataframe, schema=neededSchema, table_name=tablename, create_table=True,create_schema=True, if_row_exists='update')
    connection.commit()

def load_SQL_Data():
    db_engine = create_db_engine(db_username, db_password, db_host, db_port, db_name)
    with db_engine.connect() as connection:
        df = pd.read_sql(text('select * from soloq.top_ladder_matches'),connection)
    df = df.reset_index(drop=True)
    return df 

def get_stored_matches():
    df = load_SQL_Data()
    return df['matchId']

# %% [markdown]
# ### Obtaining Puuid Functions

# %%
# Loading dotenv file for code
load_dotenv()

# Riot Games API Key
API_Key = os.environ.get('riot_api_key')

# Global counter to track how many times the function is run
puuid_call_count = 0  # Initialize the counter to 0

# getting puuids
def get_puuid(SummonerId=None, PlayerName=None, PlayerTag=None, max_retries=5):
    """Fetches the PUUID of a player using either Summoner ID or Riot ID (PlayerName + PlayerTag)."""
    
    global puuid_call_count  # Use the global counter
    
    puuid_call_count += 1  # Increment counter every time the function is called
    
    retries = 0  # Track retry attempts

    while retries < max_retries:
        if SummonerId is not None:
            root_url = 'https://na1.api.riotgames.com'  # NA1 region for SummonerId lookup
            endpoint = f'/lol/summoner/v4/summoners/{SummonerId}'
        else:
            root_url = 'https://americas.api.riotgames.com'  # Americas region for Riot ID lookup
            endpoint = f'/riot/account/v1/accounts/by-riot-id/{PlayerName}/{PlayerTag}'

        response = requests.get(root_url + endpoint + "?api_key=" + API_Key)

        # Debugging: Show response code and function call count
        print(f"PUUID Function Call #{puuid_call_count} - URL: {root_url}{endpoint}, Response Code: {response.status_code}")

        if response.status_code == 200:
            try:
                return response.json()['puuid'], 200  # Return PUUID and success code
            except KeyError:
                print(f"Error: Missing 'puuid' in API response for {SummonerId or PlayerName}#{PlayerTag}")
                return None, 500  # Return None if JSON response doesn't have expected data

        elif response.status_code == 429:
            print(f"Rate limited on PUUID request! Waiting for 2 minutes 5 seconds before retrying ({retries+1}/{max_retries})...")
            time.sleep(125)  # Wait before retrying
            retries += 1  # Increment retry count
        else:
            print(f"Failed to retrieve PUUID. Status Code: {response.status_code}")
            return None, response.status_code  # Stop retrying on other errors

    print(f"Max retries reached for {SummonerId or PlayerName}#{PlayerTag}, skipping PUUID retrieval.")
    return None, 429  # Return None after max retries

  

#print(get_puuid(PlayerName='BoopThySnoot',PlayerTag='NA1'))

# Getting player name and tag from puuid
def get_idtag_from_puuid(puuid=None, region = 'americas'):
  # The region for this function is americas
  root_url = f'https://{region}.api.riotgames.com'
  endpoint = f'/riot/account/v1/accounts/by-puuid/{puuid}'
  # root and endpoint makes creating the links easier
  response = requests.get(root_url + endpoint + "?api_key=" + API_Key)

  # combining tag and name to be like a standard riot id
  id = {
    'playerName' : response.json()['gameName'],
    'playerTag' : response.json()['tagLine']
  }
  return id


#print(get_idtag_from_puuid(get_puuid(PlayerName='BoopThySnoot',PlayerTag='NA1'))['playerName'])

# %% [markdown]
# ### Obtaining Ladder Function

# %%
# Obtaining Challanger & Masters leagues ranked ladder

def get_ladder(top = None, region = 'na1'):
    
    # root for all leagues 
    root = f'https://{region}.api.riotgames.com'
    # differnet leagues endpoints
    chall_endpoint = '/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5'
    gm_endpoint = '/lol/league/v4/grandmasterleagues/by-queue/RANKED_SOLO_5x5'
    masters_endpoint = '/lol/league/v4/masterleagues/by-queue/RANKED_SOLO_5x5'

    #challenger df
    response = requests.get(root + chall_endpoint + "?api_key=" + API_Key)
    chall_df = pd.DataFrame(response.json()['entries']).sort_values('leaguePoints', ascending=False).reset_index(drop = True)
    chall_df

    # other dfs
    gm_df = pd.DataFrame()
    masters_df = pd.DataFrame()

    # Creating ladder df (only pulls other ladders if pull size requires)

    if top > 300: 
        response = requests.get(root + gm_endpoint + "?api_key=" + API_Key)
        gm_df = pd.DataFrame(response.json()['entries']).sort_values('leaguePoints', ascending=False).reset_index(drop = True)
    ladder = pd.concat([chall_df,gm_df,masters_df]).reset_index(drop=True)[:top] # selects x amount of players
    if top > 1000:
        response = requests.get(root + masters_endpoint + "?api_key=" + API_Key)
        masters_df = pd.DataFrame(response.json()['entries']).sort_values('leaguePoints', ascending=False).reset_index(drop = True)

    #creating representative rank column
    ladder = ladder.reset_index(drop=False).drop(columns='rank').rename(columns={'index':'rank'})
    ladder['rank'] = ladder['rank'] + 1

    #output
    return ladder

get_ladder(top = 1500)
# Out:
#      rank                                         summonerId  leaguePoints  \
# 0       1    z2T7jkJGTkNtQjXCmJSviV6Tq70JXwSM7bOT5J90kOCQP-0          1614
# 1       2    uWLwLzOWUUAe2fDmPwTQEUm0_JisdwLXqsrUM-SDb64OyEE          1603
# 2       3    we7nQGsOFGaykgQ5uW-VAduk_eC88v7yxD4KwDHFyIpgcXE          1535
# 3       4   2XpGj-IYv-JutN5mxkzYUpIP6QUYuivfvZyQmvlPALQq9FfY          1424
# 4       5    mhloXLACzmWTlqJ6lDuPrGPnkcexRJiub8iKcJDDqWts1bc          1413
# ..    ...                                                ...           ...
# 995   996    aImHDgDv0dz7fo-d1H8i9C58MUXi2djVKxJXEPD4r3M7Oxo           175
# 996   997    BF9tialellNrDpyWbxyQexTHNvIBm5eq7wk5ogi1L0rZ-nY           172
# 997   998   MTui3byKRNAwumeBv_5EK9DJli876A5Nl4RTavPmkfYv0-y1           166
# 998   999    GNF_Ir-OQ9MaUmbtQMRx5VPPccWXlBidD3fEwTzDYFEHr84           166
# 999  1000  MrzouKIX4vQng6nWC-aWqvTzbfqYxd5DDNAj9zHrTfucRw...           124
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak
# 0     116      79     True     False       False       True
# 1     124      83     True     False       False       True
# 2     104      66     True     False       False      False
# 3      82      48    False     False       False      False
# 4     101      72     True     False       False       True
# ..    ...     ...      ...       ...         ...        ...
# 995    95      76    False     False        True      False
# 996    37      31    False     False        True      False
# 997   153     166    False     False        True      False
# 998    75      65    False     False       False      False
# 999   185     177    False     False        True      False
#
# [1000 rows x 9 columns]

# %% [markdown]
# ### Obtaining Match History Functions

# %%
# Obtaining match histories 
def get_match_hist(puuid = None, start = 0, count = 20, region = 'americas', removestored = False):

  # Set up a session with retry mechanisms
  session = FuturesSession(executor=ProcessPoolExecutor(max_workers=10))
  retries = 5
  status_forcelist = [429]
  retry = Retry(
      total=retries,
      read=retries,
      connect=retries,
      respect_retry_after_header=True,
      status_forcelist=status_forcelist,
  )

  adapter = HTTPAdapter(max_retries=retry)
  session.mount('http://', adapter)
  session.mount('https://', adapter)

# Building the Url
  root_url = f'https://{region}.api.riotgames.com'
  endpoint = f'/lol/match/v5/matches/by-puuid/{puuid}/ids'
  query_params = f'?type=ranked&start={start}&count={count}'
  response = requests.get(root_url + endpoint + query_params + "&api_key=" + API_Key)
  matchIds = response.json()

  return matchIds

#print(get_match_hist(get_puuid(SummonerId= 'uWLwLzOWUUAe2fDmPwTQEUm0_JisdwLXqsrUM-SDb64OyEE'),count=10))

# getting the data from the match histories 
def get_match_data_from_id(matchId = None, region = 'americas'):

    # Set up a session with retry mechanisms
  session = FuturesSession(executor=ProcessPoolExecutor(max_workers=10))
  retries = 5
  status_forcelist = [429]
  retry = Retry(
      total=retries,
      read=retries,
      connect=retries,
      respect_retry_after_header=True,
      status_forcelist=status_forcelist,
  )

  adapter = HTTPAdapter(max_retries=retry)
  session.mount('http://', adapter)
  session.mount('https://', adapter)

  # building the url
  root_url = f'https://{region}.api.riotgames.com'
  endpoint = f'/lol/match/v5/matches/{matchId}'

  response = requests.get(root_url + endpoint + "?api_key=" + API_Key)
  # Debugging: Show response code
  print(f"Match ID: {matchId}, Response Code: {response.status_code}")

  try:
      return response.json(), response.status_code  # Return both JSON and status code
  except:
      return None, response.status_code  # Return None if JSON parsing fails



#get_match_data_from_id(matchId = 'NA1_5218927642')

# %% [markdown]
# ### Processing Match History Function

# %%
# Data Processing Setup 
#game = get_match_data_from_id(matchId = 'NA1_5218927642')

def process_match_json(match_json, puuid):
    
    try: 
        # match_json should include the get_match_data_from_id() function like above ^
        # All time units are in seconds


        # Architecture 
        metadata = match_json['metadata']
        info = match_json['info']
        participants = metadata['participants']
        players = info['participants']
        player = players[participants.index(puuid)]
        teams = info['teams']
        player_team_id = player['teamId'] #100 is blueside and 200 is redside
        player_team = next((team for team in teams if team['teamId'] == player_team_id), None)
        enemy_team = next((team for team in teams if team['teamId'] != player_team_id), None)
        obj_team = player_team['objectives']
        try:
            atakhan_team = obj_team['atakhan']
        except: 
            atakhan_team = None
        baron_team = obj_team['baron']
        dragon_team = obj_team['dragon']
        voidGrubs_team = obj_team['horde']
        riftHerald_team = obj_team['riftHerald']
        perks = player['perks']
        stats = perks['statPerks']
        styles = perks['styles']
        primary = styles[0]
        secondary = styles[1]

        # Match metadata
        matchId = metadata['matchId']
        participants = metadata['participants']

        # Match information
        endOfGameResult = info['endOfGameResult'] # this needs to return 'GameComplete'
        gameCreation = info['gameCreation']
        gameDuration = info['gameDuration']
        gameEndTimestamp =  info['gameEndTimestamp']
        gameId = info['gameId']
        patch = info['gameVersion']

        # player information
        riotIdGameName = player['riotIdGameName']
        riotIdTagline = player['riotIdTagline']
        summonerName = player['summonerName']

        # kda information
        kills = player['kills']
        deaths = player['deaths']
        assists = player['assists']
        firstBloodKill = player['firstBloodKill'] 
        firstBloodAssist = player['firstBloodAssist']
        doubleKills = player['doubleKills']
        tripleKills = player['tripleKills']
        quadraKills = player['quadraKills']
        pentaKills = player['pentaKills']
        unrealKills = player['unrealKills']
        largestMultiKill = player['largestMultiKill']
        killingSprees = player['killingSprees']
        largestKillingSpree = player['largestKillingSpree']
        teamKills = player_team['objectives']['champion']['kills']

        # Time information
        timePlayed = player['timePlayed']
        longestTimeSpentLiving = player['longestTimeSpentLiving']
        totalTimeSpentDead = player['totalTimeSpentDead']
        perctTimeDead = round((totalTimeSpentDead / timePlayed) * 100, 2)

        # Minion kill info
        cs = player['totalMinionsKilled']
        neutralMinionsKilled = player['neutralMinionsKilled']
        totalAllyJungleMinionsKilled = player['totalAllyJungleMinionsKilled']
        totalEnemyJungleMinionsKilled = player['totalEnemyJungleMinionsKilled']

        # Ping info
        OMWPing = player['onMyWayPings']
        allInPings = player['allInPings']
        assistMePings = player['assistMePings']
        enemyMissingPings = player['enemyMissingPings']
        enemyVisionPings = player['enemyVisionPings']
        holdPings = player['holdPings']
        getBackPings = player['getBackPings']
        needVisionPings = player['needVisionPings']
        pushPings = player['pushPings']

        # vision info
        visionScore = player['visionScore']
        visionClearedPings = player['visionClearedPings']
        visionWardsBoughtInGame = player['visionWardsBoughtInGame']
        wardsKilled = player['wardsKilled']
        wardsPlaced = player['wardsPlaced']
        sightWardsBoughtInGame = player['sightWardsBoughtInGame']
        detectorWardsPlaced = player['detectorWardsPlaced']

        # Major objective info
        baronKills = player['baronKills']
        dragonKills = player['dragonKills']
        damageDealtToObjectives = player['damageDealtToObjectives']
        objectivesStolen = player['objectivesStolen']
        objectivesStolenAssists = player['objectivesStolenAssists']

        # turret info
        turretKills = player['turretKills']
        turretTakedowns = player['turretTakedowns']
        turretsLost = player['turretsLost']
        firstTowerAssist = player['firstTowerAssist']
        firstTowerKill = player['firstTowerKill']
        damageDealtToBuildings = player['damageDealtToBuildings']
        damageDealtToTurrets = player['damageDealtToTurrets']

        # inhib info
        inhibitorKills = player['inhibitorKills']
        inhibitorTakedowns = player['inhibitorTakedowns']
        inhibitorsLost = player['inhibitorsLost']

        # game position
        teamPosition = player['teamPosition']
        lane = player['lane']
        role = player['role']

        # champion info
        championName = player['championName']
        champExperience = player['champExperience']
        champLevel = player['champLevel']
        championTransform = player['championTransform']

        # Perk info
        primary_style = primary['style']
        secondary_style = secondary['style']

        primary_keystone = primary['selections'][0]['perk']
        primary_perk_1 = primary['selections'][1]['perk']
        primary_perk_2 = primary['selections'][2]['perk']
        primary_perk_3 = primary['selections'][3]['perk']

        secondary_perk_1 = secondary['selections'][0]['perk']
        secondary_perk_2 = secondary['selections'][1]['perk']

        # summoner spells
        summoner1Id = player['summoner1Id']
        summoner2Id = player['summoner2Id']

        # Champion Stat info
        defense = stats['defense']
        flex = stats['flex']
        offense = stats['offense']

        # gold info
        goldEarned = player['goldEarned']
        goldSpent = player['goldSpent']
        bountyLevel = player['bountyLevel']

        # item info
        item0 = player['item0']
        item1 = player['item1']
        item2 = player['item2']
        item3 = player['item3']
        item4 = player['item4']
        item5 = player['item5']
        item6 = player['item6']
        itemsPurchased = player['itemsPurchased']
        consumablesPurchased = player['consumablesPurchased']

        # Interaction info
        totalDamageDealt = player['totalDamageDealt']
        magicDamageDealt = player['magicDamageDealt']
        physicalDamageDealt = player['physicalDamageDealt']
        trueDamageDealt = player['trueDamageDealt']

        totalDamageDealtToChampions = player['totalDamageDealtToChampions']
        magicDamageDealtToChampions = player['magicDamageDealtToChampions']
        physicalDamageDealtToChampions = player['physicalDamageDealtToChampions']
        trueDamageDealtToChampions = player['trueDamageDealtToChampions']

        totalDamageTaken = player['totalDamageTaken']
        magicDamageTaken = player['magicDamageTaken']
        physicalDamageTaken = player['physicalDamageTaken']
        trueDamageTaken = player['trueDamageTaken']

        totalHeal = player['totalHeal']
        totalUnitsHealed = player['totalUnitsHealed']
        totalHealsOnTeammates = player['totalHealsOnTeammates']
        totalDamageShieldedOnTeammates = player['totalDamageShieldedOnTeammates']
        damageSelfMitigated = player['damageSelfMitigated']

        timeCCingOthers = player['timeCCingOthers']
        totalTimeCCDealt = player['totalTimeCCDealt']

        # team objectives
        if atakhan_team is not None:
            atakhan_killed = atakhan_team['first']
        else:
            atakhan_killed =  'False'
        baron_first = baron_team['first']
        baron_kills = baron_team['kills']
        dragon_first = dragon_team['first']
        dragon_kills = dragon_team['kills']
        voidGrubs_first = voidGrubs_team['first']
        voidGrubs_kills = voidGrubs_team['kills']
        riftHerald_first =  riftHerald_team['first']
        riftHerald_kills = riftHerald_team['kills']

        # Team champion info 
        # Initialize lists for blue and red side champions
        blue_side_champions = []
        red_side_champions = []

        # Loop through all players and categorize champions by team
        for playerr in players:
            player_Champion = playerr['championName']
            team_id = playerr['teamId']  # Get player's team ID
            
            if team_id == 100:
                blue_side_champions.append(player_Champion)
            elif team_id == 200:
                red_side_champions.append(player_Champion)

        # Create a dictionary separating blue and red side champions
        champion_dict = {
            "Blue_Side": blue_side_champions,
            "Red_Side": red_side_champions
        }

        # Assign blue side champions to individual variables
        blue_champ1, blue_champ2, blue_champ3, blue_champ4, blue_champ5 = blue_side_champions

        # Assign red side champions to individual variables
        red_champ1, red_champ2, red_champ3, red_champ4, red_champ5 = red_side_champions

        # Game outcome
        win = player['win']
        
        # creating dataframe from match json
        matchDF = pd.DataFrame({
            'matchId': [matchId],
            'participants': [participants],
            'puuid' : [puuid],
            'endOfGameResult': [endOfGameResult],
            'gameCreation': [gameCreation],
            'gameDuration': [gameDuration],
            'gameEndTimestamp': [gameEndTimestamp],
            'gameId': [gameId],
            'patch': [patch],
            'riotIdGameName': [riotIdGameName],
            'riotIdTagline': [riotIdTagline],
            'summonerName': [summonerName],
            'kills': [kills],
            'deaths': [deaths],
            'assists': [assists],
            'firstBloodKill': [firstBloodKill],
            'firstBloodAssist': [firstBloodAssist],
            'doubleKills': [doubleKills],
            'tripleKills': [tripleKills],
            'quadraKills': [quadraKills],
            'pentaKills': [pentaKills],
            'unrealKills': [unrealKills],
            'largestMultiKill': [largestMultiKill],
            'killingSprees': [killingSprees],
            'largestKillingSpree': [largestKillingSpree],
            'teamKills': [teamKills],
            'timePlayed': [timePlayed],
            'longestTimeSpentLiving': [longestTimeSpentLiving],
            'totalTimeSpentDead': [totalTimeSpentDead],
            'perctTimeDead': [perctTimeDead],
            'cs': [cs],
            'neutralMinionsKilled': [neutralMinionsKilled],
            'totalAllyJungleMinionsKilled': [totalAllyJungleMinionsKilled],
            'totalEnemyJungleMinionsKilled': [totalEnemyJungleMinionsKilled],
            'OMWPing': [OMWPing],
            'allInPings': [allInPings],
            'assistMePings': [assistMePings],
            'enemyMissingPings': [enemyMissingPings],
            'enemyVisionPings': [enemyVisionPings],
            'holdPings': [holdPings],
            'getBackPings': [getBackPings],
            'needVisionPings': [needVisionPings],
            'pushPings': [pushPings],
            'visionScore': [visionScore],
            'visionClearedPings': [visionClearedPings],
            'visionWardsBoughtInGame': [visionWardsBoughtInGame],
            'wardsKilled': [wardsKilled],
            'wardsPlaced': [wardsPlaced],
            'sightWardsBoughtInGame': [sightWardsBoughtInGame],
            'detectorWardsPlaced': [detectorWardsPlaced],
            'baronKills': [baronKills],
            'dragonKills': [dragonKills],
            'damageDealtToObjectives': [damageDealtToObjectives],
            'objectivesStolen': [objectivesStolen],
            'objectivesStolenAssists': [objectivesStolenAssists],
            'turretKills': [turretKills],
            'turretTakedowns': [turretTakedowns],
            'turretsLost': [turretsLost],
            'firstTowerAssist': [firstTowerAssist],
            'firstTowerKill': [firstTowerKill],
            'damageDealtToBuildings': [damageDealtToBuildings],
            'damageDealtToTurrets': [damageDealtToTurrets],
            'inhibitorKills': [inhibitorKills],
            'inhibitorTakedowns': [inhibitorTakedowns],
            'inhibitorsLost': [inhibitorsLost],
            'teamPosition': [teamPosition],
            'lane': [lane],
            'role': [role],
            'championName': [championName],
            'champExperience': [champExperience],
            'champLevel': [champLevel],
            'championTransform': [championTransform],
            'primary_style': [primary_style],
            'secondary_style': [secondary_style],
            'primary_keystone': [primary_keystone],
            'primary_perk_1': [primary_perk_1],
            'primary_perk_2': [primary_perk_2],
            'primary_perk_3': [primary_perk_3],
            'secondary_perk_1': [secondary_perk_1],
            'secondary_perk_2': [secondary_perk_2],
            'summoner1Id': [summoner1Id],
            'summoner2Id': [summoner2Id],
            'defense': [defense],
            'flex': [flex],
            'offense': [offense],
            'goldEarned': [goldEarned],
            'goldSpent': [goldSpent],
            'bountyLevel': [bountyLevel],
            'item0': [item0],
            'item1': [item1],
            'item2': [item2],
            'item3': [item3],
            'item4': [item4],
            'item5': [item5],
            'wardTypeBought': [item6],
            'itemsPurchased': [itemsPurchased],
            'consumablesPurchased': [consumablesPurchased],
            'totalDamageDealt': [totalDamageDealt],
            'magicDamageDealt': [magicDamageDealt],
            'physicalDamageDealt': [physicalDamageDealt],
            'trueDamageDealt': [trueDamageDealt],
            'totalDamageDealtToChampions': [totalDamageDealtToChampions],
            'magicDamageDealtToChampions': [magicDamageDealtToChampions],
            'physicalDamageDealtToChampions': [physicalDamageDealtToChampions],
            'trueDamageDealtToChampions': [trueDamageDealtToChampions],
            'totalDamageTaken': [totalDamageTaken],
            'magicDamageTaken': [magicDamageTaken],
            'physicalDamageTaken': [physicalDamageTaken],
            'trueDamageTaken': [trueDamageTaken],
            'totalHeal': [totalHeal],
            'totalUnitsHealed': [totalUnitsHealed],
            'totalHealsOnTeammates': [totalHealsOnTeammates],
            'totalDamageShieldedOnTeammates': [totalDamageShieldedOnTeammates],
            'damageSelfMitigated': [damageSelfMitigated],
            'timeCCingOthers': [timeCCingOthers],
            'totalTimeCCDealt': [totalTimeCCDealt],
            'atakhan_killed': [atakhan_killed],
            'playerSide' : [player_team_id],
            'blue_champ1' : [blue_champ1],
            'blue_champ2' : [blue_champ2],
            'blue_champ3' : [blue_champ3],
            'blue_champ4' : [blue_champ4],
            'blue_champ5' : [blue_champ5],
            'red_champ1' : [red_champ1],
            'red_champ2' : [red_champ2],
            'red_champ3' : [red_champ3],
            'red_champ4' : [red_champ4],
            'red_champ5' : [red_champ5],
            'baron_first': [baron_first],
            'baron_kills': [baron_kills],
            'dragon_first': [dragon_first],
            'dragon_kills': [dragon_kills],
            'voidGrubs_first': [voidGrubs_first],
            'voidGrubs_kills': [voidGrubs_kills],
            'riftHerald_first': [riftHerald_first],
            'riftHerald_kills': [riftHerald_kills],
            'win': [win]
        })

        return matchDF
    except:
        return pd.DataFrame()

# %% [markdown]
# ### Making Values Readable Functions

# %%
def convert_df_ids(df):   
 # Url links to get the names for each of the ids
    champ_name = 'https://raw.communitydragon.org/latest/plugins/rcp-be-lol-game-data/global/default/v1/champion-summary.json'
    perks = 'https://raw.communitydragon.org/latest/plugins/rcp-be-lol-game-data/global/default/v1/perks.json'
    perkstyles = 'https://raw.communitydragon.org/latest/plugins/rcp-be-lol-game-data/global/default/v1/perkstyles.json'
    summoner_spells = 'https://raw.communitydragon.org/latest/plugins/rcp-be-lol-game-data/global/default/v1/summoner-spells.json'
    item_names = 'https://raw.communitydragon.org/latest/plugins/rcp-be-lol-game-data/global/default/v1/items.json'

    # converting ids to json 
    champ_name_json = requests.get(champ_name).json()
    perks_json = requests.get(perks).json()
    perkstyles_json = requests.get(perkstyles).json()
    summoner_spells_json = requests.get(summoner_spells).json()
    item_names_json =  requests.get(item_names).json()

    # Function to extract id-name pairs from each JSON
    def extract_id_name(data):
        # Initialize an empty dictionary
        id_name_dict = {}
        
        # Loop through each item in the list (or adjust based on structure)
        if isinstance(data, list):
            for item in data:
                # Assuming each item has 'id' and 'name' keys
                id_name_dict[item['id']] = item['name']
        elif isinstance(data, dict):
            # Handle the case where data is a dictionary
            for key, item in data.items():
                if isinstance(item, list):
                    for sub_item in item:
                        id_name_dict[sub_item['id']] = sub_item['name']
                        
        return id_name_dict

    # Extract id-name pairs for each JSON
    champ_name_dict = extract_id_name(champ_name_json)
    perks_dict = extract_id_name(perks_json)
    perkstyles_dict = extract_id_name(perkstyles_json)
    summoner_spells_dict = extract_id_name(summoner_spells_json)
    item_names_dict = extract_id_name(item_names_json)

    # replacing values into data frame
    df['championName'] = df['championName'].replace(champ_name_dict)
    df[['primary_style','secondary_style']] = df[['primary_style','secondary_style']].replace(perkstyles_dict)
    df[['primary_keystone','primary_perk_1','primary_perk_2','primary_perk_3','secondary_perk_1','secondary_perk_2']]= df[['primary_keystone','primary_perk_1','primary_perk_2','primary_perk_3','secondary_perk_1','secondary_perk_2']].replace(perks_dict)
    df[['summoner1Id','summoner2Id']] = df[['summoner1Id','summoner2Id']].replace(summoner_spells_dict)
    df[['item0','item1','item2','item3','item4','item5','wardTypeBought']] = df[['item0','item1','item2','item3','item4','item5','wardTypeBought']].replace(item_names_dict)

    # replacing player side with text
    df['playerSide'] = df['playerSide'].replace({100: 'Blue', 200: 'Red'})

    return df

# %% [markdown]
# ### Obtaining Match Data Function

# %%
def get_data(players_wanted=None, ladder_start=None, match_count=None):
    # Get ladder data 
    ladder = get_ladder(players_wanted+ladder_start)
    ladder = pd.DataFrame(ladder['summonerId'][ladder_start:])
    summonerIds = ladder['summonerId'].to_list()

    # Convert summoner IDs to PUUIDs with rate-limiting handling
    puuids = {}
    for sumid in summonerIds:
        while True:  # Keep retrying if status code is 429
            puuid, status_code = get_puuid(sumid)

            if status_code == 200:
                puuids[sumid] = puuid  # Store valid PUUID
                break  # Exit loop on success
            elif status_code == 429:
                print(f"Rate limited on PUUID request! Waiting for 2 minutes 5 seconds before retrying summoner {sumid}...")
                time.sleep(125)  # Wait for 2 minutes  5 seconds before retrying
            else:
                print(f"Failed to retrieve PUUID for summoner {sumid}. Status Code: {status_code}")
                break  # Stop retrying on other errors

    # Get match histories and store them in a dictionary
    match_dict = {}  # {match_id: [puuid1, puuid2, ...]}
    for summoner_id, puuid in puuids.items():
        match_ids = get_match_hist(puuid, count=match_count)
        for match_id in match_ids:
            if match_id not in match_dict:
                match_dict[match_id] = []  # Initialize list if match_id is new
            match_dict[match_id].append(puuid)  # Append PUUID instead of overwriting

    # List to collect DataFrames
    dataframes = []

    # Loop through matches and collect DataFrames
    for match_id, puid_list in match_dict.items():
        while True:  # Keep retrying if status code is 429
            game, status_code = get_match_data_from_id(matchId=match_id)
            
            if status_code == 200:
                break  # Valid response, exit loop
            elif status_code == 429:
                print(f"Rate limited on match data! Waiting for 2 minutes 5 seconds before retrying match {match_id}...")
                time.sleep(125)  # Wait for 2 minutes 5 seconds before retrying
            else:
                print(f"Failed to retrieve match {match_id}. Status Code: {status_code}")
                break  # Stop retrying on other errors

        if game and status_code == 200:
            for puid in puid_list:  # Process for each PUUID in the match
                matchDF = process_match_json(game, puuid=puid)

                print(f"Processing Match ID: {match_id}, PUUID: {puid}, DataFrame Shape: {matchDF.shape}")  # Debugging print
                matchDF = convert_df_ids(matchDF)
                matchDF['uuid'] = matchDF['matchId'] + '_' + matchDF['puuid']
                matchDF = matchDF.set_index('uuid')
                upload_data_into_sql(matchDF, 'soloq', 'top_ladder_matches')
                print(f"Match: {match_id} has been fully processed and uploaded to SQL")

                # Ensure matchDF is not empty before appending
                if not matchDF.empty:
                    dataframes.append(matchDF)
                    print(f'There are currently {len(dataframes)} columns!, processed {round(len(dataframes)/25,2)} players. ')

    # Concatenate all dataframes
    df = pd.concat(dataframes, ignore_index=True) if dataframes else pd.DataFrame()

    return df

# %% [markdown]
# ### Converting Data to CSV

# %%
# get the data set
get_data(players_wanted = 100, ladder_start=349,  match_count=25)
# Out:
# PUUID Function Call #322 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/bC0z57qggwXcjxOH9GL_pCcbaO7r_nPjSSk15cjTxoP0PTI, Response Code: 200
# PUUID Function Call #323 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/op-vV0DCvuS5kb3tl_pTo0VhC-C_brALF28-BhLe0EYbVUc, Response Code: 200
# PUUID Function Call #324 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/t2S3BUTBxch1D-KuIb7DdRkU-QSqUmIYLseE2qDse7ydNvQ, Response Code: 200
# PUUID Function Call #325 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/zZwC3LGcNvwVNrX1hOYKxIkUyqokYxs4bLevABpdfNn5JQs, Response Code: 200
# PUUID Function Call #326 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/Z_Qa0jMOTkxxkUoFCKvyLfw4yhcPl7RXHDjbfb3jV4fZe9M, Response Code: 200
# PUUID Function Call #327 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/KNc3WchDthM5SqYDS_EQhlbgbNrvCJ-ycjl5SA43Guvdbao, Response Code: 200
# PUUID Function Call #328 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/HjM8gKwMiu7np2Jxm5lA_QHSiLeEqRddvB-8cxqnE3EP41s, Response Code: 200
# PUUID Function Call #329 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/wOaJBt8leZ1bYWluTGu0-Kuo0oBxDmiEsqcAVdK9xZ7OmPl6etSAglJVBg, Response Code: 200
# PUUID Function Call #330 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/ig3y50sjEDnG5am3W82EYrv4PQnX7sPReQWv1EdvgytJnQ8E, Response Code: 200
# PUUID Function Call #331 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/9BQKvg0Y8zAGuPLFtcK_ATm6Y_10GhSN-Bd5gcWvtE43Y08, Response Code: 200
# PUUID Function Call #332 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/OAlENhuXDZaNn3wQIPHkqArvVYCas1fYusL8QZd_UW2fzTovh6x5mwiW5w, Response Code: 200
# PUUID Function Call #333 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/9i8ml1OuN7f27_X4J7VRQdVYDK02ymk9zOfv4vppyjKpZ-U, Response Code: 200
# PUUID Function Call #334 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/9391l3HgqvvgskloD5wX0vHpeyDvJTh_g-4Zn7SXRdv_AEU, Response Code: 200
# PUUID Function Call #335 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/4uBLqk8-gqyXfVGjRfA7WRHYKhAO5L_g3OOfvYcd_XUtYZ_FjuqrGhZptA, Response Code: 200
# PUUID Function Call #336 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/aisH7T_tALkTMj6hbW8a5x5J6PyTdGvasQ6qMGlOQ8VisNkyiNs4ijb0-A, Response Code: 200
# PUUID Function Call #337 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/6P7I5n6XYC9GcM7Y9I2Ch6qEBaywZIB1M1y22JrpoecsPWE, Response Code: 200
# PUUID Function Call #338 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/ybHC1UJF_KMN_5L7eqap0T4EEj3xR0g7A3YAm81-AfiPULjo, Response Code: 200
# PUUID Function Call #339 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/IYv9z2jCWlRFBNuRUH2E7HL1g-Znms1KI6OTljkp6Mm4ABQk16o_lZn6mQ, Response Code: 200
# PUUID Function Call #340 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/YOjfPJxUf2Yr-VSWdE_h0hW_MxCLR7z2v6HAIpPMzsHyvioA_tnqEMUzqg, Response Code: 200
# PUUID Function Call #341 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/K_LIFpjeyme3Hg6lrzzqhSjjRu9cI4XfnJUcgUGPO9TZVOXf, Response Code: 200
# PUUID Function Call #342 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/7oQCffA5fHDf_1TRAA5z_QveSi5RRhmKv30NjMUvIJylTWw, Response Code: 200
# PUUID Function Call #343 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/q1vqm-geaDF6sC_ICMfVV3ZvffAi462zPUdztC96TFZck54W5EC7Jray7w, Response Code: 200
# PUUID Function Call #344 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/g4pFia_0ZO53ZDP1FSMa3sciRvNdfFrr7Q11gT8tWLdZEr8, Response Code: 200
# PUUID Function Call #345 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/tR1ZukCLeWFJcHQkOzPNpB0inP2bf0tOF66p7ASoT_M2GBE, Response Code: 200
# PUUID Function Call #346 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/_gtbSILIrxdOpNZeDdJv0BJq-gpIrh-hWcAKconKDopSgUM, Response Code: 200
# PUUID Function Call #347 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/8Bf-k_HbhhlI91vf9mlbsV6-Nmds56ytXep4mKBfJuLxI1o, Response Code: 200
# PUUID Function Call #348 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/4uhwkOkrzs6XxWjbGwqnGi44gmiV6cl5ltRhSgKlTKbsiAJ7, Response Code: 200
# PUUID Function Call #349 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/DeR8rfggp1hbJaiMWuI8mTOHBgEuLi_2bP-YChdloeEOPOo, Response Code: 200
# PUUID Function Call #350 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/eBtVj6wbNs8lvvjCw0yXM0Qo05AwPqepkOGhES6MHEtfSQQaharAX1SLLg, Response Code: 200
# PUUID Function Call #351 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/Bn3ICwbVXE0bioRGJWE8oZv-fbHcPTyEnmxFlhj671_qIOqV, Response Code: 200
# PUUID Function Call #352 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/NiZtA0Gz1Z6rbf3eVlQ0yl3SlbD5ZSaw4fKVZrHsq7myzJQ, Response Code: 200
# PUUID Function Call #353 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/Pf0zRcIjkB68IEHcXkbzOOt752KuNM19e-ETepT9Qn5eoeE, Response Code: 200
# PUUID Function Call #354 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/RbazJueh_1Qey0dY_SAhMapR-qP_fxEzn1wghV_g91MuqDfwGSu86t3P8Q, Response Code: 200
# PUUID Function Call #355 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/eAzlavto-Y9jY4XDjxgebIHg_VOWcUR8ExyNHH50-JuyVrw, Response Code: 200
# PUUID Function Call #356 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/ip9dhzNSXyI_fqwHHX560_2c7LnagHfppO0xVtkPRCMnzXw, Response Code: 200
# PUUID Function Call #357 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/hictrM2eM4JexEpIHV4o3wxLA5vSk9VVxw3-NfIH5DZ0Wn0, Response Code: 200
# PUUID Function Call #358 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/uHOwNHpE2CORak6mGtJSEMU4JOO3CnGH0D1dbc9TXUQWFlQ, Response Code: 200
# PUUID Function Call #359 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/yhsS1L7J2x3kk6Wzv1DTFlY232erEnWo5Wf_FQavIBSqLco, Response Code: 200
# PUUID Function Call #360 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/w4WpqARwUS91jJyPBpYbWx_WGrE9AzNIkDe4RbMqlCgHuv2nJgMd75blCg, Response Code: 200
# PUUID Function Call #361 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/izgsYpeREl5PH16oMvQzWKxex-I9shxY5BvgFaKLeznA_hM, Response Code: 200
# PUUID Function Call #362 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/VgsI8Ho1Ti-pkTgTDbAWYwHFxqJnEqWuECyDe9YQ9IbFKSLC, Response Code: 200
# PUUID Function Call #363 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/F0PzKabidiC9SsgFWnMXvAXE3KU_ERd0dmjMTHjoap68zfHe9wLUXciYpA, Response Code: 200
# PUUID Function Call #364 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/6y9LBqyrfW89Yz5IoHgWupzGV1yNUJ2mllupJZEQ5nwiwAU, Response Code: 200
# PUUID Function Call #365 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/zTPIp9r6hXf6GBojiDAtfcbpPBBIkeBEQd-kRJZdmXbd6vwxu__zgEeAbw, Response Code: 200
# PUUID Function Call #366 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/aIWMqWfTXL9UcBz9mDbD4xdZazrMlvJ1ASblWs-skgJgrno, Response Code: 200
# PUUID Function Call #367 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/4HEeXDRpkRrWmBZGgkD_CpNxAgRjvBMJA-T-8DQlo8KHq1h8, Response Code: 200
# PUUID Function Call #368 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/PdPhT6TLZaTbgnpPc2HZlYFrbYMzoZEQugS1STMdbQvVlaI, Response Code: 200
# PUUID Function Call #369 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/RizL1OPwFPDM7RszHgrqd85LU3UTYuI8I5MrjqkMPQKivsY, Response Code: 200
# PUUID Function Call #370 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/PZhXGsCghPW0Nmb3eEQ6aXvUFaA5t6yT3LtKGgIymGNCNFk, Response Code: 200
# PUUID Function Call #371 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/gbLQpnQDR6YwxU5GVoPW_Mjp7XnBGCS5fl-X1tcuZ92SxNj8ToZqOmbnBw, Response Code: 200
# PUUID Function Call #372 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/81-MqjwkVq4hvDxYUMvbREnxx5aFAOzcSuKmn521rvqxGfs, Response Code: 200
# PUUID Function Call #373 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/3M9Iz-hPMqXnZbwp_QbI8rB4XYqGuiKo00Kt9ybkSoyCl317qLLvMLZOMw, Response Code: 200
# PUUID Function Call #374 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/F1cFFg2a2nic2qG7RkxNkIkzhKjD_HeuIN9-wvhx33ZGzwC8, Response Code: 200
# PUUID Function Call #375 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/SsvDX8bAB6E277tatbfmR_wrPdbPtv3IBaMgtkJVqozBKhk, Response Code: 200
# PUUID Function Call #376 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/9BMBVSSLkVsDAUWSpjlZipnI4UAT2mjvzwGCV-CLd6jMy_U, Response Code: 200
# PUUID Function Call #377 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/1BAXZiggW9kFSaB3FHUJb1lhTOZ0iWJ5Zn_Wff3apaBQtWjH, Response Code: 200
# PUUID Function Call #378 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/DFr60MYvIJlvNMx_-NIBAVJl-2J2AUPOkPJ4jykzBzsoIZs, Response Code: 200
# PUUID Function Call #379 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/O-B5pO5lESBY4bWeVBvm2Ljd1M65Lwh0xERyJTaeaDb3Txw, Response Code: 200
# PUUID Function Call #380 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/V87qaGacC9H_su6oJ4HF1ajzTdW2GtJzv-emO1kC1wVLY03CJa26I8tCZA, Response Code: 200
# PUUID Function Call #381 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/qCfMYnSGkCpgGlWfM7a0CLiF2yDCX5aW9eI2_ysYZ9Kl1vI, Response Code: 200
# PUUID Function Call #382 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/7i-4p-MgXSClAvhSTJFVV8GNdrBhaT1xRbW5I_x4-XNAlZ9UU5UHQTN5Ww, Response Code: 200
# PUUID Function Call #383 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/BioTd-kipNOLGCiANLM0p_J9_eo6dM5TxdrXROlAVlP6OJUOxrlLwpwx7g, Response Code: 200
# PUUID Function Call #384 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/qdps2FZjtydCdbA-KsmkQyvj6vla7C4GGva6ukptBNyfF-43M4gp9wUmfQ, Response Code: 200
# PUUID Function Call #385 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/jU7Dnk-ho83JvLR2wEJQZSA1dRqhn08ACJtRNXoWH_v5NWs, Response Code: 200
# PUUID Function Call #386 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/uZaAlTpxruItNYusoiDw1qStCiQPs79ZW8VRYopGR1hNIkGu_VTvfov7Cw, Response Code: 200
# PUUID Function Call #387 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/JPRXx0SttnaX6gv_8mndkMvmEnWp9UFWbpHB7v2dnddnbrec2CZhddqlUw, Response Code: 200
# PUUID Function Call #388 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/Ec_-bELyXUkzpItFEkBPrd4o_jkq8hq3ECEK79Khzg_9Q8I, Response Code: 200
# PUUID Function Call #389 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/oU3JKsZWq09xVFZBEUeYm56A4ltp5MTLaXGhzOktIPpvHDq-JjhaR3aDhw, Response Code: 200
# PUUID Function Call #390 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/mX55JXc52YvYoRTAY8qfU1-kknlSvRAEf4g26sR8uvevako, Response Code: 200
# PUUID Function Call #391 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/NZJkGlCNbgscfYe9LKEbPj0c9juU_rzW0FxYs-S7EGlxaCM, Response Code: 200
# PUUID Function Call #392 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/7wkRyc9nQPYFrIp9mPAJgTX1UszpVztUXaIpoH4O_nsw9YpvLhpZFTOmaA, Response Code: 200
# PUUID Function Call #393 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/gLASsT05MJLgmdUY-hMrjQM1Brj1HG5PPlhsCScmeHSzCTlV, Response Code: 200
# PUUID Function Call #394 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/8TWcOAQ4G-90OxPN4vZ8mweQ3jFshWHn_ATNkP2fAEIg4pU, Response Code: 200
# PUUID Function Call #395 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/IjvyyE7hBSEX9oiWGiWThoH6KyVT-M0KHIncl0Gz21Z36Gkz, Response Code: 200
# PUUID Function Call #396 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/6ihzqgJZw0D8zo8cFOpYena0KGTG6z97T6jxAoZQg_p8dOY, Response Code: 200
# PUUID Function Call #397 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/EBzwpzc6GMFUa2YDaVufZRoDfAuwVftnmNWno6A0nxInpgc, Response Code: 200
# PUUID Function Call #398 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/_OVsrRGvYNdXqlz9y0WDb8IWr-7oaD7cH8_sKeo05Trl4lGSvOgVUCJCfQ, Response Code: 200
# PUUID Function Call #399 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/E6-p3SQx80rXo2YV779juiMtVmryEE-D2Sw1piPzJTD5AN0, Response Code: 200
# PUUID Function Call #400 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/sBXXQf79tGn8qkzxz0CW0RnXlFpZnZPtUe9-7HZ6KBG1LffiJhJ1PKchLw, Response Code: 200
# PUUID Function Call #401 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/rbJws8fcJkVA-on_ig0jGe5tSxZzmbh-TEu6hgEpAlObe5Vb2sRDRK7-Zg, Response Code: 200
# PUUID Function Call #402 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/Aocs1nnkTofue8XZfz_F7PMBqAYBfQI8ZfYJP6SIgkj7d3s, Response Code: 200
# PUUID Function Call #403 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/-_0b-roWWxEiJrAiQAoZCY9mdN2NtKIBKE9wcaawZQAeXEF5QmhhaUUqww, Response Code: 200
# PUUID Function Call #404 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/yu1yRmDILrvP4KmvroOratA6ag822rp21Ol1a1lowDk2gdi3iBfTPGSwQQ, Response Code: 200
# PUUID Function Call #405 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/jQEE3fjBrUQTPUQCXRrJfQHRkHIZwyP2-KZIQpai3eVd2CeSUYLWHfg1jQ, Response Code: 200
# PUUID Function Call #406 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/fEdKodBqQbDRuqkXccOXK258xzoT8yiCWsRiXTAyKO4TIwtSF88rLzmE8A, Response Code: 200
# PUUID Function Call #407 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/17wPkthdZLAa735YK8zvpczi8Pee7vlfp43MfBiOGGO4iB5h4lsbMVvtiA, Response Code: 200
# PUUID Function Call #408 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/Td2Ok-THlRnhrBlO9RRWI8G_jJe8j0Cb9VxdYv1kkL0ZNMza, Response Code: 200
# PUUID Function Call #409 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/1uAEt6XcCdRomeif3pZYNmVxgrHlWe1pr39okh0x08bWAtI, Response Code: 200
# PUUID Function Call #410 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/QviVZc9YHn4wTka6Psn9w0dkaq-6swA0KDSrxb32ku_M8g0, Response Code: 200
# PUUID Function Call #411 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/xYoN2pkh3HUOM5mE0vA0DS8flWUWAhqS0agAf2UKjb8_RpJH, Response Code: 200
# PUUID Function Call #412 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/o2QdB2sjk7OTOcZN_4tU-6rSVUSUhOhvccO5Rb9ar82FBNet, Response Code: 200
# PUUID Function Call #413 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/NGl0eY_4oc2pDZaSHeTWQ23w8Yquw1723tv2a8CnTDH7EyLq, Response Code: 200
# PUUID Function Call #414 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/DR_B0lwKwN2Xd5ZdFigDA3dAxapgTN2Mm-6Y76378EZVFyU, Response Code: 200
# PUUID Function Call #415 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/tQiHa1FiaTtS0UbOstJdjFjnoKFtOgXfA-g6ygMQf-4uKYeS_wff-xJsXQ, Response Code: 200
# PUUID Function Call #416 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/NEloLu-Q3beaqMJHMxOgL3kVBti_Qfn9MwCw8cDDNyOIau3sD7NeJHWSnA, Response Code: 200
# PUUID Function Call #417 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/CREvHI_YMyhvbi_60pbAN8hjVD8Xi3Hji7TSEZrHIzhP9Vg, Response Code: 200
# PUUID Function Call #418 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/FferkPojLRbsntzDP12D7EyzurzIi45RstqfwDL7mva99mU, Response Code: 200
# PUUID Function Call #419 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/BhRqHJv8si87J0_6KROEp7tm-eKq2EPUjemSgwXJqUBvIJI, Response Code: 200
# PUUID Function Call #420 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/Ijz7eL7kyOb6CE085qyRgHOC1HNxZmBZzZRXQV7GWsRX1-g, Response Code: 429
# Rate limited on PUUID request! Waiting for 2 minutes 5 seconds before retrying (1/5)...
# PUUID Function Call #420 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/Ijz7eL7kyOb6CE085qyRgHOC1HNxZmBZzZRXQV7GWsRX1-g, Response Code: 200
# PUUID Function Call #421 - URL: https://na1.api.riotgames.com/lol/summoner/v4/summoners/YTAXcnUs9Jzrnrx2Cn5Tgx5xgEVvYeFf25p61IQ3H2w3k9-X, Response Code: 200
# Match ID: NA1_5220895243, Response Code: 429
# Rate limited on match data! Waiting for 2 minutes 5 seconds before retrying match NA1_5220895243...
# Match ID: NA1_5220895243, Response Code: 200
# Processing Match ID: NA1_5220895243, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5220895243 has been fully processed and uploaded to SQL
# There are currently 1 columns!, processed 0.04 players.
# Match ID: NA1_5218232059, Response Code: 200
# Processing Match ID: NA1_5218232059, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5218232059 has been fully processed and uploaded to SQL
# There are currently 2 columns!, processed 0.08 players.
# Match ID: NA1_5218188388, Response Code: 200
# Processing Match ID: NA1_5218188388, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5218188388 has been fully processed and uploaded to SQL
# There are currently 3 columns!, processed 0.12 players.
# Processing Match ID: NA1_5218188388, PUUID: VNP2Fy4hGubm-Tq_PioYR2PiD0raBD_6QoUvtShlE4ubJe6O19hrFxXTMhceSBDtAut4kXh16qh6mA, DataFrame Shape: (1, 137)
# Match: NA1_5218188388 has been fully processed and uploaded to SQL
# There are currently 4 columns!, processed 0.16 players.
# Match ID: NA1_5218162250, Response Code: 200
# Processing Match ID: NA1_5218162250, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5218162250 has been fully processed and uploaded to SQL
# There are currently 5 columns!, processed 0.2 players.
# Match ID: NA1_5218126162, Response Code: 200
# Processing Match ID: NA1_5218126162, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5218126162 has been fully processed and uploaded to SQL
# There are currently 6 columns!, processed 0.24 players.
# Match ID: NA1_5218094115, Response Code: 200
# Processing Match ID: NA1_5218094115, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5218094115 has been fully processed and uploaded to SQL
# There are currently 7 columns!, processed 0.28 players.
# Match ID: NA1_5218075609, Response Code: 200
# Processing Match ID: NA1_5218075609, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5218075609 has been fully processed and uploaded to SQL
# There are currently 8 columns!, processed 0.32 players.
# Match ID: NA1_5218047449, Response Code: 200
# Processing Match ID: NA1_5218047449, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5218047449 has been fully processed and uploaded to SQL
# There are currently 9 columns!, processed 0.36 players.
# Processing Match ID: NA1_5218047449, PUUID: dlqJpTjAHoGf7gLEeko60W0yac67II2ObF2F8li0fD5lnofdlrJ0VmMoH0MQggEHN5-Kao1oWm-WsA, DataFrame Shape: (1, 137)
# Match: NA1_5218047449 has been fully processed and uploaded to SQL
# There are currently 10 columns!, processed 0.4 players.
# Match ID: NA1_5218018728, Response Code: 200
# Processing Match ID: NA1_5218018728, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5218018728 has been fully processed and uploaded to SQL
# There are currently 11 columns!, processed 0.44 players.
# Match ID: NA1_5218003947, Response Code: 200
# Processing Match ID: NA1_5218003947, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5218003947 has been fully processed and uploaded to SQL
# There are currently 12 columns!, processed 0.48 players.
# Match ID: NA1_5217982420, Response Code: 200
# Processing Match ID: NA1_5217982420, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217982420 has been fully processed and uploaded to SQL
# There are currently 13 columns!, processed 0.52 players.
# Match ID: NA1_5217968723, Response Code: 200
# Processing Match ID: NA1_5217968723, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217968723 has been fully processed and uploaded to SQL
# There are currently 14 columns!, processed 0.56 players.
# Match ID: NA1_5217916359, Response Code: 200
# Processing Match ID: NA1_5217916359, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217916359 has been fully processed and uploaded to SQL
# There are currently 15 columns!, processed 0.6 players.
# Match ID: NA1_5217553130, Response Code: 200
# Processing Match ID: NA1_5217553130, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217553130 has been fully processed and uploaded to SQL
# There are currently 16 columns!, processed 0.64 players.
# Match ID: NA1_5217518886, Response Code: 200
# Processing Match ID: NA1_5217518886, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217518886 has been fully processed and uploaded to SQL
# There are currently 17 columns!, processed 0.68 players.
# Match ID: NA1_5217482647, Response Code: 200
# Processing Match ID: NA1_5217482647, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217482647 has been fully processed and uploaded to SQL
# There are currently 18 columns!, processed 0.72 players.
# Processing Match ID: NA1_5217482647, PUUID: 6P0ZilmurpaglRjC_tmkXcQi0yDt2Cb7AuAV_WrIARjxJKNFakC7zjuAYB3jmyZAHIrakv1B_JAsOA, DataFrame Shape: (1, 137)
# Match: NA1_5217482647 has been fully processed and uploaded to SQL
# There are currently 19 columns!, processed 0.76 players.
# Match ID: NA1_5217457619, Response Code: 200
# Processing Match ID: NA1_5217457619, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217457619 has been fully processed and uploaded to SQL
# There are currently 20 columns!, processed 0.8 players.
# Processing Match ID: NA1_5217457619, PUUID: b_7a8jwoVC_os6S2ryiNtfy9a91dmNHAzBfPKRqMlpyy2zQ7Ww_1qnCKGFsjqJhE7f-y8cM5-I58Nw, DataFrame Shape: (1, 137)
# Match: NA1_5217457619 has been fully processed and uploaded to SQL
# There are currently 21 columns!, processed 0.84 players.
# Match ID: NA1_5217431148, Response Code: 200
# Processing Match ID: NA1_5217431148, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217431148 has been fully processed and uploaded to SQL
# There are currently 22 columns!, processed 0.88 players.
# Processing Match ID: NA1_5217431148, PUUID: Ksen2XWteJO3hhggi4eebFrDB9ldbyz23Hzn6hXU1AA73VR5ovSS2tVsWlnQ-pZjMQ5-onTjyocGyw, DataFrame Shape: (1, 137)
# Match: NA1_5217431148 has been fully processed and uploaded to SQL
# There are currently 23 columns!, processed 0.92 players.
# Match ID: NA1_5217405828, Response Code: 200
# Processing Match ID: NA1_5217405828, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217405828 has been fully processed and uploaded to SQL
# There are currently 24 columns!, processed 0.96 players.
# Match ID: NA1_5217373115, Response Code: 200
# Processing Match ID: NA1_5217373115, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217373115 has been fully processed and uploaded to SQL
# There are currently 25 columns!, processed 1.0 players.
# Match ID: NA1_5217367019, Response Code: 200
# Processing Match ID: NA1_5217367019, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217367019 has been fully processed and uploaded to SQL
# There are currently 26 columns!, processed 1.04 players.
# Match ID: NA1_5217339660, Response Code: 200
# Processing Match ID: NA1_5217339660, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217339660 has been fully processed and uploaded to SQL
# There are currently 27 columns!, processed 1.08 players.
# Match ID: NA1_5217322346, Response Code: 200
# Processing Match ID: NA1_5217322346, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217322346 has been fully processed and uploaded to SQL
# There are currently 28 columns!, processed 1.12 players.
# Match ID: NA1_5217297762, Response Code: 200
# Processing Match ID: NA1_5217297762, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5217297762 has been fully processed and uploaded to SQL
# There are currently 29 columns!, processed 1.16 players.
# Match ID: NA1_5216279873, Response Code: 200
# Processing Match ID: NA1_5216279873, PUUID: 28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoEcmZ19zGEMc0YAgaF2QlrF2HiZra3wqSw, DataFrame Shape: (1, 137)
# Match: NA1_5216279873 has been fully processed and uploaded to SQL
# There are currently 30 columns!, processed 1.2 players.
# Match ID: NA1_5221747070, Response Code: 200
# Processing Match ID: NA1_5221747070, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221747070 has been fully processed and uploaded to SQL
# There are currently 31 columns!, processed 1.24 players.
# Match ID: NA1_5221704121, Response Code: 200
# Processing Match ID: NA1_5221704121, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221704121 has been fully processed and uploaded to SQL
# There are currently 32 columns!, processed 1.28 players.
# Processing Match ID: NA1_5221704121, PUUID: fu97lDTvUfylFrAWVSSWprCzgJ1xRY8bac1HA8huMQUuuiMyYuY3uTsbbcvqL89EeHVtlQD56EsqYA, DataFrame Shape: (1, 137)
# Match: NA1_5221704121 has been fully processed and uploaded to SQL
# There are currently 33 columns!, processed 1.32 players.
# Processing Match ID: NA1_5221704121, PUUID: PQby432Pf0tjOb5zCKgjZ37mGvSAXWTUndtYboKLs8YCGGdUBd5fY-ABJgEJUWpS-dugbrUa6tHYpA, DataFrame Shape: (1, 137)
# Match: NA1_5221704121 has been fully processed and uploaded to SQL
# There are currently 34 columns!, processed 1.36 players.
# Match ID: NA1_5221673552, Response Code: 200
# Processing Match ID: NA1_5221673552, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221673552 has been fully processed and uploaded to SQL
# There are currently 35 columns!, processed 1.4 players.
# Processing Match ID: NA1_5221673552, PUUID: xRRjIgbm-4Ho-bPG7BUskfJE7IngsB-JyN-a4hA_n_jHYxbvr_8AdwAgNg41bZCJr4fjukm6ClxyEA, DataFrame Shape: (1, 137)
# Match: NA1_5221673552 has been fully processed and uploaded to SQL
# There are currently 36 columns!, processed 1.44 players.
# Match ID: NA1_5221655370, Response Code: 200
# Processing Match ID: NA1_5221655370, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221655370 has been fully processed and uploaded to SQL
# There are currently 37 columns!, processed 1.48 players.
# Match ID: NA1_5221626800, Response Code: 200
# Processing Match ID: NA1_5221626800, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221626800 has been fully processed and uploaded to SQL
# There are currently 38 columns!, processed 1.52 players.
# Match ID: NA1_5221604059, Response Code: 200
# Processing Match ID: NA1_5221604059, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221604059 has been fully processed and uploaded to SQL
# There are currently 39 columns!, processed 1.56 players.
# Match ID: NA1_5221417641, Response Code: 200
# Processing Match ID: NA1_5221417641, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221417641 has been fully processed and uploaded to SQL
# There are currently 40 columns!, processed 1.6 players.
# Processing Match ID: NA1_5221417641, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5221417641 has been fully processed and uploaded to SQL
# There are currently 41 columns!, processed 1.64 players.
# Match ID: NA1_5221215095, Response Code: 200
# Processing Match ID: NA1_5221215095, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221215095 has been fully processed and uploaded to SQL
# There are currently 42 columns!, processed 1.68 players.
# Processing Match ID: NA1_5221215095, PUUID: _J3YolFWrP-XlL7aqwAWoOni-Iv0hQt22GimdhSQ3i_p2M9ubU5dV1TVS9aOeQV7fU9YhIk5cLiVSA, DataFrame Shape: (1, 137)
# Match: NA1_5221215095 has been fully processed and uploaded to SQL
# There are currently 43 columns!, processed 1.72 players.
# Match ID: NA1_5221170510, Response Code: 200
# Processing Match ID: NA1_5221170510, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221170510 has been fully processed and uploaded to SQL
# There are currently 44 columns!, processed 1.76 players.
# Processing Match ID: NA1_5221170510, PUUID: gxmL81du292cwuF9Wv3pvAj_-RXr2DXvQ7TVi1JvIYheBfaqrFlVEzBr7d6PiqJkNNQJRT626H9gMQ, DataFrame Shape: (1, 137)
# Match: NA1_5221170510 has been fully processed and uploaded to SQL
# There are currently 45 columns!, processed 1.8 players.
# Match ID: NA1_5221131355, Response Code: 200
# Processing Match ID: NA1_5221131355, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221131355 has been fully processed and uploaded to SQL
# There are currently 46 columns!, processed 1.84 players.
# Processing Match ID: NA1_5221131355, PUUID: VNP2Fy4hGubm-Tq_PioYR2PiD0raBD_6QoUvtShlE4ubJe6O19hrFxXTMhceSBDtAut4kXh16qh6mA, DataFrame Shape: (1, 137)
# Match: NA1_5221131355 has been fully processed and uploaded to SQL
# There are currently 47 columns!, processed 1.88 players.
# Processing Match ID: NA1_5221131355, PUUID: Br0sUGuB-bq2K7Md9rbPoYfX1nE_hDtBV2nSCSspcb8O2IWwFpGcu7oyDXmQpTcwKiDVh-s_FIc8mQ, DataFrame Shape: (1, 137)
# Match: NA1_5221131355 has been fully processed and uploaded to SQL
# There are currently 48 columns!, processed 1.92 players.
# Match ID: NA1_5221084329, Response Code: 200
# Processing Match ID: NA1_5221084329, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221084329 has been fully processed and uploaded to SQL
# There are currently 49 columns!, processed 1.96 players.
# Processing Match ID: NA1_5221084329, PUUID: Cze7GHaoHgAVteRcxwZYhaXu52oo80C6AbkUpI0YwlaHwe5bL4fF0KE2o3HSqNexW7631DBOhHTFWg, DataFrame Shape: (1, 137)
# Match: NA1_5221084329 has been fully processed and uploaded to SQL
# There are currently 50 columns!, processed 2.0 players.
# Match ID: NA1_5221034537, Response Code: 200
# Processing Match ID: NA1_5221034537, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221034537 has been fully processed and uploaded to SQL
# There are currently 51 columns!, processed 2.04 players.
# Match ID: NA1_5221017149, Response Code: 200
# Processing Match ID: NA1_5221017149, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5221017149 has been fully processed and uploaded to SQL
# There are currently 52 columns!, processed 2.08 players.
# Match ID: NA1_5220985358, Response Code: 200
# Processing Match ID: NA1_5220985358, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220985358 has been fully processed and uploaded to SQL
# There are currently 53 columns!, processed 2.12 players.
# Match ID: NA1_5220959069, Response Code: 200
# Processing Match ID: NA1_5220959069, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220959069 has been fully processed and uploaded to SQL
# There are currently 54 columns!, processed 2.16 players.
# Processing Match ID: NA1_5220959069, PUUID: q62uicgUpBdOIqa1m4VR4XznL1M9Px48xHOHWkYlLDUzL4XabIiseVPU2jpAqOg3r7eP7ufPVotjBQ, DataFrame Shape: (1, 137)
# Match: NA1_5220959069 has been fully processed and uploaded to SQL
# There are currently 55 columns!, processed 2.2 players.
# Match ID: NA1_5220926343, Response Code: 200
# Processing Match ID: NA1_5220926343, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220926343 has been fully processed and uploaded to SQL
# There are currently 56 columns!, processed 2.24 players.
# Processing Match ID: NA1_5220926343, PUUID: LOglirQAGEA-woFNKQnrADtKo7C7pfQZhbm0grF1CWoxHWW029inCNQYuUN8S3Z4qtNXOYqhRyTExw, DataFrame Shape: (1, 137)
# Match: NA1_5220926343 has been fully processed and uploaded to SQL
# There are currently 57 columns!, processed 2.28 players.
# Processing Match ID: NA1_5220926343, PUUID: nblcT4qJ-f_bpwWB4oUd-J4isthO5RyBVbe3iAvN5GNIFenkQuytLVAXy2V5g8QdcjGL2rdDVAmgZQ, DataFrame Shape: (1, 137)
# Match: NA1_5220926343 has been fully processed and uploaded to SQL
# There are currently 58 columns!, processed 2.32 players.
# Match ID: NA1_5220889919, Response Code: 200
# Processing Match ID: NA1_5220889919, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220889919 has been fully processed and uploaded to SQL
# There are currently 59 columns!, processed 2.36 players.
# Match ID: NA1_5220542717, Response Code: 200
# Processing Match ID: NA1_5220542717, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220542717 has been fully processed and uploaded to SQL
# There are currently 60 columns!, processed 2.4 players.
# Processing Match ID: NA1_5220542717, PUUID: BjBfLBpgeo-VQd1fq6ZA3XvdbyilBmaTTD8XUHlygf6gr5dZ3eeF406Fq4UIkIXqdFRjyO0lPMKznA, DataFrame Shape: (1, 137)
# Match: NA1_5220542717 has been fully processed and uploaded to SQL
# There are currently 61 columns!, processed 2.44 players.
# Processing Match ID: NA1_5220542717, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220542717 has been fully processed and uploaded to SQL
# There are currently 62 columns!, processed 2.48 players.
# Match ID: NA1_5220491429, Response Code: 200
# Processing Match ID: NA1_5220491429, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220491429 has been fully processed and uploaded to SQL
# There are currently 63 columns!, processed 2.52 players.
# Processing Match ID: NA1_5220491429, PUUID: IHOQ4R3dFFIOpmDWM-fBdVMZm82zRJWZqLhq-Qo01upFFriiXuQpyxqkk0VoI--CqswfAmI-1ubbaw, DataFrame Shape: (1, 137)
# Match: NA1_5220491429 has been fully processed and uploaded to SQL
# There are currently 64 columns!, processed 2.56 players.
# Processing Match ID: NA1_5220491429, PUUID: sNQPoygzakhK1wEid75KZwfy-TfEd5cZRfm0RuCXY90jzieORIjorM9ho7EjYx75DiXP8raNZXd_nQ, DataFrame Shape: (1, 137)
# Match: NA1_5220491429 has been fully processed and uploaded to SQL
# There are currently 65 columns!, processed 2.6 players.
# Match ID: NA1_5220462625, Response Code: 200
# Processing Match ID: NA1_5220462625, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220462625 has been fully processed and uploaded to SQL
# There are currently 66 columns!, processed 2.64 players.
# Match ID: NA1_5220426374, Response Code: 200
# Processing Match ID: NA1_5220426374, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220426374 has been fully processed and uploaded to SQL
# There are currently 67 columns!, processed 2.68 players.
# Match ID: NA1_5220390213, Response Code: 200
# Processing Match ID: NA1_5220390213, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220390213 has been fully processed and uploaded to SQL
# There are currently 68 columns!, processed 2.72 players.
# Match ID: NA1_5220322184, Response Code: 200
# Processing Match ID: NA1_5220322184, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220322184 has been fully processed and uploaded to SQL
# There are currently 69 columns!, processed 2.76 players.
# Processing Match ID: NA1_5220322184, PUUID: VNP2Fy4hGubm-Tq_PioYR2PiD0raBD_6QoUvtShlE4ubJe6O19hrFxXTMhceSBDtAut4kXh16qh6mA, DataFrame Shape: (1, 137)
# Match: NA1_5220322184 has been fully processed and uploaded to SQL
# There are currently 70 columns!, processed 2.8 players.
# Match ID: NA1_5220305483, Response Code: 200
# Processing Match ID: NA1_5220305483, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220305483 has been fully processed and uploaded to SQL
# There are currently 71 columns!, processed 2.84 players.
# Match ID: NA1_5220279891, Response Code: 200
# Processing Match ID: NA1_5220279891, PUUID: XPGwm9anlQDdlj8ruBO0uhxmy3D4e77s_ym-kzqv6bEGYABOcxz3Oq9usAspISBS9mPy0IgBooMuVw, DataFrame Shape: (1, 137)
# Match: NA1_5220279891 has been fully processed and uploaded to SQL
# There are currently 72 columns!, processed 2.88 players.
# Processing Match ID: NA1_5220279891, PUUID: TF4i38h3ZTV17krhPTgaoNDFcvi4kZNejZIW1hD50jkuk5RGDsxusS5tV2zyTI2snu_ircb4pKa1yA, DataFrame Shape: (1, 137)
# Match: NA1_5220279891 has been fully processed and uploaded to SQL
# There are currently 73 columns!, processed 2.92 players.
# Processing Match ID: NA1_5220279891, PUUID: mqkS3e0MN8R-YUWP8FRFTbAgE5nkD3AxlQWDBV8o055CYVUfiG_2ii5oGY-zKYPEFfJawOXUE70dAw, DataFrame Shape: (1, 137)
# Match: NA1_5220279891 has been fully processed and uploaded to SQL
# There are currently 74 columns!, processed 2.96 players.
# Match ID: NA1_5221757300, Response Code: 200
# Processing Match ID: NA1_5221757300, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5221757300 has been fully processed and uploaded to SQL
# There are currently 75 columns!, processed 3.0 players.
# Processing Match ID: NA1_5221757300, PUUID: Jo4HQujZAmEkwxQxRVTbUkosuwQWHTzImH7PYxeKvuN2E_a-cf4bQ1qraLYHUt2EFQSVhim_6E2-sg, DataFrame Shape: (1, 137)
# Match: NA1_5221757300 has been fully processed and uploaded to SQL
# There are currently 76 columns!, processed 3.04 players.
# Match ID: NA1_5221741046, Response Code: 200
# Processing Match ID: NA1_5221741046, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5221741046 has been fully processed and uploaded to SQL
# There are currently 77 columns!, processed 3.08 players.
# Processing Match ID: NA1_5221741046, PUUID: XEnlCfiUrbA9oL7SaMivHvbUF0ZW4QqRvHoRcz7DtQn12EjnaDb1bSXyJfX8a1w8jj2o2oe8cCIwvA, DataFrame Shape: (1, 137)
# Match: NA1_5221741046 has been fully processed and uploaded to SQL
# There are currently 78 columns!, processed 3.12 players.
# Match ID: NA1_5221606592, Response Code: 200
# Processing Match ID: NA1_5221606592, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5221606592 has been fully processed and uploaded to SQL
# There are currently 79 columns!, processed 3.16 players.
# Match ID: NA1_5221597568, Response Code: 200
# Processing Match ID: NA1_5221597568, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5221597568 has been fully processed and uploaded to SQL
# There are currently 80 columns!, processed 3.2 players.
# Match ID: NA1_5221589716, Response Code: 200
# Processing Match ID: NA1_5221589716, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5221589716 has been fully processed and uploaded to SQL
# There are currently 81 columns!, processed 3.24 players.
# Match ID: NA1_5220891500, Response Code: 200
# Processing Match ID: NA1_5220891500, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5220891500 has been fully processed and uploaded to SQL
# There are currently 82 columns!, processed 3.28 players.
# Processing Match ID: NA1_5220891500, PUUID: a50ydO_IRKrOe0RWrgGpn6S2R2rUIx1bEhpKqw9KOSawLvSKbHi5K1eXJqeBoZTlZIBrwwU6ShZ-PA, DataFrame Shape: (1, 137)
# Match: NA1_5220891500 has been fully processed and uploaded to SQL
# There are currently 83 columns!, processed 3.32 players.
# Match ID: NA1_5220873815, Response Code: 200
# Processing Match ID: NA1_5220873815, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5220873815 has been fully processed and uploaded to SQL
# There are currently 84 columns!, processed 3.36 players.
# Processing Match ID: NA1_5220873815, PUUID: OVF_U2I6mdHv_h6rAARh0TKVeGyFF3JDm4NQuOhAE1qsHqaOoQLBFOW3SkyV3J5Ctl_PWSF8eU7NNQ, DataFrame Shape: (1, 137)
# Match: NA1_5220873815 has been fully processed and uploaded to SQL
# There are currently 85 columns!, processed 3.4 players.
# Processing Match ID: NA1_5220873815, PUUID: fp-4SKuBSNN_kGcqRycju2BRRks6dcI97uey-dBvf3YELdwrVhSzm_C_-E19Lk7zbC6__mMeT9i7gQ, DataFrame Shape: (1, 137)
# Match: NA1_5220873815 has been fully processed and uploaded to SQL
# There are currently 86 columns!, processed 3.44 players.
# Processing Match ID: NA1_5220873815, PUUID: FqnhWkbqcOCuEuq8Q3-WeGAI0m-YZgU_PpHK_YkOKarzPVy3D-x09xc_7LK1ZaerwS4lyIkATjBQ1w, DataFrame Shape: (1, 137)
# Match: NA1_5220873815 has been fully processed and uploaded to SQL
# There are currently 87 columns!, processed 3.48 players.
# Match ID: NA1_5220853271, Response Code: 200
# Processing Match ID: NA1_5220853271, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5220853271 has been fully processed and uploaded to SQL
# There are currently 88 columns!, processed 3.52 players.
# Match ID: NA1_5220838255, Response Code: 200
# Processing Match ID: NA1_5220838255, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5220838255 has been fully processed and uploaded to SQL
# There are currently 89 columns!, processed 3.56 players.
# Processing Match ID: NA1_5220838255, PUUID: LOglirQAGEA-woFNKQnrADtKo7C7pfQZhbm0grF1CWoxHWW029inCNQYuUN8S3Z4qtNXOYqhRyTExw, DataFrame Shape: (1, 137)
# Match: NA1_5220838255 has been fully processed and uploaded to SQL
# There are currently 90 columns!, processed 3.6 players.
# Match ID: NA1_5220113682, Response Code: 200
# Processing Match ID: NA1_5220113682, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5220113682 has been fully processed and uploaded to SQL
# There are currently 91 columns!, processed 3.64 players.
# Match ID: NA1_5220089272, Response Code: 200
# Processing Match ID: NA1_5220089272, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5220089272 has been fully processed and uploaded to SQL
# There are currently 92 columns!, processed 3.68 players.
# Match ID: NA1_5220075830, Response Code: 200
# Processing Match ID: NA1_5220075830, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5220075830 has been fully processed and uploaded to SQL
# There are currently 93 columns!, processed 3.72 players.
# Match ID: NA1_5220057141, Response Code: 200
# Processing Match ID: NA1_5220057141, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5220057141 has been fully processed and uploaded to SQL
# There are currently 94 columns!, processed 3.76 players.
# Processing Match ID: NA1_5220057141, PUUID: mqkS3e0MN8R-YUWP8FRFTbAgE5nkD3AxlQWDBV8o055CYVUfiG_2ii5oGY-zKYPEFfJawOXUE70dAw, DataFrame Shape: (1, 137)
# Match: NA1_5220057141 has been fully processed and uploaded to SQL
# There are currently 95 columns!, processed 3.8 players.
# Match ID: NA1_5219569628, Response Code: 200
# Processing Match ID: NA1_5219569628, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5219569628 has been fully processed and uploaded to SQL
# There are currently 96 columns!, processed 3.84 players.
# Match ID: NA1_5219550371, Response Code: 200
# Processing Match ID: NA1_5219550371, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5219550371 has been fully processed and uploaded to SQL
# There are currently 97 columns!, processed 3.88 players.
# Match ID: NA1_5219527860, Response Code: 200
# Processing Match ID: NA1_5219527860, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5219527860 has been fully processed and uploaded to SQL
# There are currently 98 columns!, processed 3.92 players.
# Match ID: NA1_5219502736, Response Code: 200
# Processing Match ID: NA1_5219502736, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5219502736 has been fully processed and uploaded to SQL
# There are currently 99 columns!, processed 3.96 players.
# Processing Match ID: NA1_5219502736, PUUID: Jo4HQujZAmEkwxQxRVTbUkosuwQWHTzImH7PYxeKvuN2E_a-cf4bQ1qraLYHUt2EFQSVhim_6E2-sg, DataFrame Shape: (1, 137)
# Match: NA1_5219502736 has been fully processed and uploaded to SQL
# There are currently 100 columns!, processed 4.0 players.
# Match ID: NA1_5219483669, Response Code: 200
# Processing Match ID: NA1_5219483669, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5219483669 has been fully processed and uploaded to SQL
# There are currently 101 columns!, processed 4.04 players.
# Processing Match ID: NA1_5219483669, PUUID: Jo4HQujZAmEkwxQxRVTbUkosuwQWHTzImH7PYxeKvuN2E_a-cf4bQ1qraLYHUt2EFQSVhim_6E2-sg, DataFrame Shape: (1, 137)
# Match: NA1_5219483669 has been fully processed and uploaded to SQL
# There are currently 102 columns!, processed 4.08 players.
# Match ID: NA1_5219464863, Response Code: 200
# Processing Match ID: NA1_5219464863, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# Match: NA1_5219464863 has been fully processed and uploaded to SQL
# There are currently 103 columns!, processed 4.12 players.
# Match ID: NA1_5219439383, Response Code: 200
# Processing Match ID: NA1_5219439383, PUUID: CY3oMFQappm8j3nxSfryE0G3b5Gnc-DcN3Vf1QjJoXPAmE0QCEa-Ye43dd7oyPL4DPuisSpX3mZDAQ, DataFrame Shape: (1, 137)
# ...
# Processing Match ID: NA1_5218938532, PUUID: gxmL81du292cwuF9Wv3pvAj_-RXr2DXvQ7TVi1JvIYheBfaqrFlVEzBr7d6PiqJkNNQJRT626H9gMQ, DataFrame Shape: (1, 137)
# Match: NA1_5218938532 has been fully processed and uploaded to SQL
# There are currently 2467 columns!, processed 98.68 players.
# Match ID: NA1_5218904550, Response Code: 200
# Processing Match ID: NA1_5218904550, PUUID: gxmL81du292cwuF9Wv3pvAj_-RXr2DXvQ7TVi1JvIYheBfaqrFlVEzBr7d6PiqJkNNQJRT626H9gMQ, DataFrame Shape: (1, 137)
# Match: NA1_5218904550 has been fully processed and uploaded to SQL
# There are currently 2468 columns!, processed 98.72 players.
# Match ID: NA1_5218872633, Response Code: 200
# Processing Match ID: NA1_5218872633, PUUID: gxmL81du292cwuF9Wv3pvAj_-RXr2DXvQ7TVi1JvIYheBfaqrFlVEzBr7d6PiqJkNNQJRT626H9gMQ, DataFrame Shape: (1, 137)
# Match: NA1_5218872633 has been fully processed and uploaded to SQL
# There are currently 2469 columns!, processed 98.76 players.
# Match ID: NA1_5218839382, Response Code: 200
# Processing Match ID: NA1_5218839382, PUUID: gxmL81du292cwuF9Wv3pvAj_-RXr2DXvQ7TVi1JvIYheBfaqrFlVEzBr7d6PiqJkNNQJRT626H9gMQ, DataFrame Shape: (1, 137)
# Match: NA1_5218839382 has been fully processed and uploaded to SQL
# There are currently 2470 columns!, processed 98.8 players.
# Match ID: NA1_5218803543, Response Code: 200
# Processing Match ID: NA1_5218803543, PUUID: gxmL81du292cwuF9Wv3pvAj_-RXr2DXvQ7TVi1JvIYheBfaqrFlVEzBr7d6PiqJkNNQJRT626H9gMQ, DataFrame Shape: (1, 137)
# Match: NA1_5218803543 has been fully processed and uploaded to SQL
# There are currently 2471 columns!, processed 98.84 players.
# Match ID: NA1_5218745314, Response Code: 200
# Processing Match ID: NA1_5218745314, PUUID: gxmL81du292cwuF9Wv3pvAj_-RXr2DXvQ7TVi1JvIYheBfaqrFlVEzBr7d6PiqJkNNQJRT626H9gMQ, DataFrame Shape: (1, 137)
# Match: NA1_5218745314 has been fully processed and uploaded to SQL
# There are currently 2472 columns!, processed 98.88 players.
# Match ID: NA1_5218727791, Response Code: 200
# Processing Match ID: NA1_5218727791, PUUID: gxmL81du292cwuF9Wv3pvAj_-RXr2DXvQ7TVi1JvIYheBfaqrFlVEzBr7d6PiqJkNNQJRT626H9gMQ, DataFrame Shape: (1, 137)
# Match: NA1_5218727791 has been fully processed and uploaded to SQL
# There are currently 2473 columns!, processed 98.92 players.
# Match ID: NA1_5218050370, Response Code: 200
# Processing Match ID: NA1_5218050370, PUUID: gxmL81du292cwuF9Wv3pvAj_-RXr2DXvQ7TVi1JvIYheBfaqrFlVEzBr7d6PiqJkNNQJRT626H9gMQ, DataFrame Shape: (1, 137)
# Match: NA1_5218050370 has been fully processed and uploaded to SQL
# There are currently 2474 columns!, processed 98.96 players.
# Match ID: NA1_5221696096, Response Code: 200
# Processing Match ID: NA1_5221696096, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5221696096 has been fully processed and uploaded to SQL
# There are currently 2475 columns!, processed 99.0 players.
# Match ID: NA1_5221442329, Response Code: 200
# Processing Match ID: NA1_5221442329, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5221442329 has been fully processed and uploaded to SQL
# There are currently 2476 columns!, processed 99.04 players.
# Match ID: NA1_5221264848, Response Code: 200
# Processing Match ID: NA1_5221264848, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5221264848 has been fully processed and uploaded to SQL
# There are currently 2477 columns!, processed 99.08 players.
# Match ID: NA1_5220745124, Response Code: 200
# Processing Match ID: NA1_5220745124, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220745124 has been fully processed and uploaded to SQL
# There are currently 2478 columns!, processed 99.12 players.
# Match ID: NA1_5220738830, Response Code: 200
# Processing Match ID: NA1_5220738830, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220738830 has been fully processed and uploaded to SQL
# There are currently 2479 columns!, processed 99.16 players.
# Match ID: NA1_5220726434, Response Code: 200
# Processing Match ID: NA1_5220726434, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220726434 has been fully processed and uploaded to SQL
# There are currently 2480 columns!, processed 99.2 players.
# Match ID: NA1_5220710072, Response Code: 200
# Processing Match ID: NA1_5220710072, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220710072 has been fully processed and uploaded to SQL
# There are currently 2481 columns!, processed 99.24 players.
# Match ID: NA1_5220691696, Response Code: 200
# Processing Match ID: NA1_5220691696, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220691696 has been fully processed and uploaded to SQL
# There are currently 2482 columns!, processed 99.28 players.
# Match ID: NA1_5220659901, Response Code: 200
# Processing Match ID: NA1_5220659901, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220659901 has been fully processed and uploaded to SQL
# There are currently 2483 columns!, processed 99.32 players.
# Match ID: NA1_5220569513, Response Code: 200
# Processing Match ID: NA1_5220569513, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220569513 has been fully processed and uploaded to SQL
# There are currently 2484 columns!, processed 99.36 players.
# Match ID: NA1_5220512407, Response Code: 200
# Processing Match ID: NA1_5220512407, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220512407 has been fully processed and uploaded to SQL
# There are currently 2485 columns!, processed 99.4 players.
# Match ID: NA1_5220400693, Response Code: 200
# Processing Match ID: NA1_5220400693, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220400693 has been fully processed and uploaded to SQL
# There are currently 2486 columns!, processed 99.44 players.
# Match ID: NA1_5220337760, Response Code: 200
# Processing Match ID: NA1_5220337760, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220337760 has been fully processed and uploaded to SQL
# There are currently 2487 columns!, processed 99.48 players.
# Match ID: NA1_5220305628, Response Code: 200
# Processing Match ID: NA1_5220305628, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5220305628 has been fully processed and uploaded to SQL
# There are currently 2488 columns!, processed 99.52 players.
# Match ID: NA1_5219911893, Response Code: 200
# Processing Match ID: NA1_5219911893, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5219911893 has been fully processed and uploaded to SQL
# There are currently 2489 columns!, processed 99.56 players.
# Match ID: NA1_5219886796, Response Code: 200
# Processing Match ID: NA1_5219886796, PUUID: qrBlKsHf9bcxyMK0vaqUI8L9MzAHL1EjzihR2Jo_rKCyAllAUpXdejJlWOb84fARaX3VSUe8vq0-7g, DataFrame Shape: (1, 137)
# Match: NA1_5219886796 has been fully processed and uploaded to SQL
# There are currently 2490 columns!, processed 99.6 players.
# Match ID: NA1_5221743606, Response Code: 200
# Processing Match ID: NA1_5221743606, PUUID: CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrczOfapb9g2-bn6XKuhl19dm2-40hrAcWuQ, DataFrame Shape: (1, 137)
# Match: NA1_5221743606 has been fully processed and uploaded to SQL
# There are currently 2491 columns!, processed 99.64 players.
# Match ID: NA1_5221389501, Response Code: 200
# Processing Match ID: NA1_5221389501, PUUID: CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrczOfapb9g2-bn6XKuhl19dm2-40hrAcWuQ, DataFrame Shape: (1, 137)
# Match: NA1_5221389501 has been fully processed and uploaded to SQL
# There are currently 2492 columns!, processed 99.68 players.
# Match ID: NA1_5221312316, Response Code: 200
# Processing Match ID: NA1_5221312316, PUUID: CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrczOfapb9g2-bn6XKuhl19dm2-40hrAcWuQ, DataFrame Shape: (1, 137)
# Match: NA1_5221312316 has been fully processed and uploaded to SQL
# There are currently 2493 columns!, processed 99.72 players.
# Match ID: NA1_5221130843, Response Code: 200
# Processing Match ID: NA1_5221130843, PUUID: CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrczOfapb9g2-bn6XKuhl19dm2-40hrAcWuQ, DataFrame Shape: (1, 137)
# Match: NA1_5221130843 has been fully processed and uploaded to SQL
# There are currently 2494 columns!, processed 99.76 players.
# Match ID: NA1_5220527626, Response Code: 200
# Processing Match ID: NA1_5220527626, PUUID: CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrczOfapb9g2-bn6XKuhl19dm2-40hrAcWuQ, DataFrame Shape: (1, 137)
# Match: NA1_5220527626 has been fully processed and uploaded to SQL
# There are currently 2495 columns!, processed 99.8 players.
# Match ID: NA1_5220493381, Response Code: 200
# Processing Match ID: NA1_5220493381, PUUID: CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrczOfapb9g2-bn6XKuhl19dm2-40hrAcWuQ, DataFrame Shape: (1, 137)
# Match: NA1_5220493381 has been fully processed and uploaded to SQL
# There are currently 2496 columns!, processed 99.84 players.
# Match ID: NA1_5220412767, Response Code: 200
# Processing Match ID: NA1_5220412767, PUUID: CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrczOfapb9g2-bn6XKuhl19dm2-40hrAcWuQ, DataFrame Shape: (1, 137)
# Match: NA1_5220412767 has been fully processed and uploaded to SQL
# There are currently 2497 columns!, processed 99.88 players.
# Match ID: NA1_5220140392, Response Code: 200
# Processing Match ID: NA1_5220140392, PUUID: CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrczOfapb9g2-bn6XKuhl19dm2-40hrAcWuQ, DataFrame Shape: (1, 137)
# Match: NA1_5220140392 has been fully processed and uploaded to SQL
# There are currently 2498 columns!, processed 99.92 players.
# Match ID: NA1_5220074552, Response Code: 200
# Processing Match ID: NA1_5220074552, PUUID: CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrczOfapb9g2-bn6XKuhl19dm2-40hrAcWuQ, DataFrame Shape: (1, 137)
# Match: NA1_5220074552 has been fully processed and uploaded to SQL
# There are currently 2499 columns!, processed 99.96 players.
# Match ID: NA1_5220065513, Response Code: 200
# Processing Match ID: NA1_5220065513, PUUID: CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrczOfapb9g2-bn6XKuhl19dm2-40hrAcWuQ, DataFrame Shape: (1, 137)
# Match: NA1_5220065513 has been fully processed and uploaded to SQL
# There are currently 2500 columns!, processed 100.0 players.
#              matchId                                       participants  \
# 0     NA1_5220895243  [CKLzJP-o0SBiLr84rVBA9ofU_8jEBy-J8qS0R8Tvk2Y2A...
# 1     NA1_5218232059  [6zCdXlWgFwYURRyU5M0my98ejzsK9gmF3V8NTarLYoS0T...
# 2     NA1_5218188388  [VNP2Fy4hGubm-Tq_PioYR2PiD0raBD_6QoUvtShlE4ubJ...
# 3     NA1_5218188388  [VNP2Fy4hGubm-Tq_PioYR2PiD0raBD_6QoUvtShlE4ubJ...
# 4     NA1_5218162250  [nIBVc52_S-qd-SoRi2LrekMSpO-mRwylhLFADLJvoP4Sa...
# ...              ...                                                ...
# 2495  NA1_5220493381  [rp-rsNa2olXpRbSFGhsXvqIWAxAlFuMSAyG_bdM_BXELH...
# 2496  NA1_5220412767  [zWoHTDwWW1ytSSKr9as3BSvLryDqMYOXkOoYGuudZrsE2...
# 2497  NA1_5220140392  [Vzw_NUiBxigEy6ptpihqvoWgLPhpZanMsOOcu4asvZg1E...
# 2498  NA1_5220074552  [W5p2o62YIwI3XfpTnO850qMgmdLx_G0VePhK6vAZF7Ee9...
# 2499  NA1_5220065513  [CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrc...
#
#                                                   puuid endOfGameResult  \
# 0     28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoE...    GameComplete
# 1     28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoE...    GameComplete
# 2     28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoE...    GameComplete
# 3     VNP2Fy4hGubm-Tq_PioYR2PiD0raBD_6QoUvtShlE4ubJe...    GameComplete
# 4     28N79qGVmATrVL2bukfEL0Jp6OD-ockswYu7QteXtHMNoE...    GameComplete
# ...                                                 ...             ...
# 2495  CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrcz...    GameComplete
# 2496  CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrcz...    GameComplete
# 2497  CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrcz...    GameComplete
# 2498  CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrcz...    GameComplete
# 2499  CKiZ207O4n56udhuy6k7edbQsL339I-V9hqXpM2beMQrcz...    GameComplete
#
#        gameCreation  gameDuration  gameEndTimestamp      gameId  \
# 0     1738522476616          1438     1738523932218  5220895243
# 1     1738206904034          1188     1738208113578  5218232059
# 2     1738204205513          2255     1738206482173  5218188388
# 3     1738204205513          2255     1738206482173  5218188388
# 4     1738202521073          1358     1738203914550  5218162250
# ...             ...           ...               ...         ...
# 2495  1738468880520          1687     1738470596353  5220493381
# 2496  1738463628465          1801     1738465455130  5220412767
# 2497  1738441143298          1602     1738442763206  5220140392
# 2498  1738434230206          1691     1738435940641  5220074552
# 2499  1738433062162           633     1738433721517  5220065513
#
#               patch   riotIdGameName  ... red_champ5 baron_first  baron_kills  \
# 0     15.2.652.1536         L0GOONJG  ...    Alistar       False            0
# 1     15.2.652.1536         L0GOONJG  ...       Lulu       False            0
# 2     15.2.652.1536         L0GOONJG  ...       Lulu        True            2
# 3     15.2.652.1536  softboy vietnam  ...       Lulu        True            2
# 4     15.2.652.1536         L0GOONJG  ...      Karma       False            0
# ...             ...              ...  ...        ...         ...          ...
# 2495  15.2.652.1536           Ashμri  ...       Rell       False            0
# 2496  15.2.652.1536           Ashμri  ...     Zilean       False            0
# 2497  15.2.652.1536           Ashμri  ...     Soraka       False            0
# 2498  15.2.652.1536           Ashμri  ...      Janna        True            1
# 2499  15.2.652.1536           Ashμri  ...       Sona       False            0
#
#       dragon_first  dragon_kills  voidGrubs_first  voidGrubs_kills  \
# 0             True             1            False                0
# 1             True             2             True                6
# 2             True             3            False                0
# 3             True             3            False                0
# 4            False             2             True                6
# ...            ...           ...              ...              ...
# 2495         False             0            False                5
# 2496         False             2            False                5
# 2497         False             0             True                1
# 2498         False             2            False                3
# 2499         False             0             True                3
#
#       riftHerald_first  riftHerald_kills    win
# 0                False                 0  False
# 1                 True                 1   True
# 2                 True                 1  False
# 3                 True                 1  False
# 4                 True                 1   True
# ...                ...               ...    ...
# 2495              True                 1  False
# 2496              True                 1  False
# 2497             False                 0  False
# 2498             False                 0   True
# 2499             False                 0   True
#
# [2500 rows x 137 columns]

# %%
# Checking that the data was loading into the frame
df = load_SQL_Data()
df.shape

# saving the data into a csv file
#df.to_csv('C:\\Users\\Kadin\\Desktop\\DS Capstone\\LOLChallengerData.csv', index=False)
